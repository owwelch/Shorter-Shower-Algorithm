# %%
import os
import csv
import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# # Learning Rate: $10^{-4}$

# %%
for n in range(0,10):
    with open(f'2^{n}_neurons_Start.csv') as f:
        reader = csv.reader(f)
        data = list(reader)
        print(f'{n}: {min([float(x) for x in data[0]])}')
# Out:
# 0: 0.18239805102348328
# 1: 0.03893379867076874
# 2: 0.024675119668245316
# 3: 0.03547447547316551
# 4: 0.003571336157619953
# 5: 0.04636970907449722
# 6: 0.0063288528472185135
# 7: 0.002984897466376424
# 8: 0.0016885687364265323
# 9: 0.024901751428842545

# %%
 with open('2^0_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
 with open('2^1_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
with open('2^2_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
with open('2^3_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
with open('2^4_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
with open('2^5_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
with open('2^6_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
with open('2^7_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
with open('2^8_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
with open('2^9_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
for n in range(1,10):
    with open(f'2^{n}_neurons_End.csv') as f:
        reader = csv.reader(f)
        data = list(reader)
        print(f'{n}: {min([float(x) for x in data[0]])}')
# Out:
# 1: 0.03439817950129509
# 2: 0.009175396524369717
# 3: 0.02114175632596016
# 4: 0.003087543649598956
# 5: 0.014866256155073643
# 6: 0.009276635013520718
# 7: 0.011010542511940002
# 8: 0.0032311654649674892
# 9: 0.004519897047430277

# %%
with open('2^1_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
with open('2^2_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
with open('2^3_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
with open('2^4_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
data[0].index(min(data[0]))
# Out:
# 993085

# %%
with open('2^5_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
with open('2^6_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
with open('2^7_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
with open('2^8_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
data[0].index(min(data[0]))
# Out:
# 890236

# %%
with open('2^9_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %% [markdown]
# # Learning Rate: $10^{-5}$

# %%
for n in range(1,10):
    with open(f'2^{n}_neurons_Start.csv') as f:
        reader = csv.reader(f)
        data = list(reader)
        print(f'{n}: {min([float(x) for x in data[0]])}')
# Out:
# 1: 0.17303204536437988
# 2: 0.024744635447859764
# 3: 0.06938093155622482
# 4: 0.023454975336790085
# 5: 0.08871407061815262
# 6: 0.11046157777309418
# 7: 0.044753555208444595
# 8: 0.025339309126138687
# 9: 0.09539227932691574

# %%
 with open('2^1_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
 with open('2^2_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
 with open('2^3_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
 with open('2^4_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
 with open('2^5_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
 with open('2^6_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
 with open('2^7_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
 with open('2^8_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
 with open('2^8_neurons_Start.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[0]])

# %%
for n in range(1,10):
    with open(f'2^{n}_neurons_End.csv') as f:
        reader = csv.reader(f)
        data = list(reader)
        print(f'{n}: {min([float(x) for x in data[1]])}')
# Out:
# 1: 0.06576481461524963
# 2: 0.0586148165166378
# 3: 0.021525269374251366
# 4: 0.023986442014575005
# 5: 0.007692062761634588
# 6: 0.029800577089190483
# 7: 0.015261635184288025
# 8: 0.00432868767529726
# 9: 0.01862122304737568

# %%
 with open('2^1_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[1]])

# %%
 with open('2^2_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[1]])

# %%
 with open('2^3_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[1]])

# %%
 with open('2^4_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[1]])

# %%
 with open('2^5_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[1]])

# %%
 with open('2^6_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[1]])

# %%
 with open('2^7_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[1]])

# %%
 with open('2^8_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[1]])

# %%
 with open('2^9_neurons_End.csv') as f:
    reader = csv.reader(f)
    data = list(reader)
    plt.plot([float(x) for x in data[1]])
